# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1, 50, 100)

# %%
plt.style.use('dark_background')
# plt.style.use('default')

# %%
plt.hist(data, color="purple", bins=20, width=2)
plt.show()

# %%
plt.hist(data, color="blue", bins=20, histtype="step")
plt.show()

# %%
plt.boxplot(data)

plt.show()

# %%
plt.boxplot(data, patch_artist=True, tick_labels=["Label see"], zorder=5)

plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N))**2
clors = np.random.rand(N)

# %%
plt.scatter(x, y, s=area, c=clors, alpha=0.5, marker=".")
plt.show()
