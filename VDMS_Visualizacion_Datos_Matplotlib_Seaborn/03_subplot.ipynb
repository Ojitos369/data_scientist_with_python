# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %% [markdown]
# plt.subplot(filas, columnas, indice_actual)

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r')
plt.subplot(2, 1, 2)
plt.hist(x)

plt.show()

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y, 'r--')
plt.plot(y, x, 'bD:')
plt.subplot(2, 2, 3)
plt.pie(x)
plt.subplot(2, 2, 4)
plt.pie(y)

plt.show()
