# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10, 10, 100)

# %%
def g(x):
    return x ** 3 + np.sin(x)

def f(x):
    return np.tan(x)

y = f(g(x))

plt.plot(x, y)
plt.show()
