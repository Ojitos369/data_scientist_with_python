# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./files/athletes_new.csv')
ed = df.copy()
df.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   function country_code country country_full nationality nationality_full  \
# 0  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 1  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  height  weight  disciplines  \
# 0              MEX       0     0.0  ['Archery']
# 1              MEX       0     0.0  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %% [markdown]
# ### Drop Columns

# %%
ed.drop("function", axis=1).head(2)
# ed
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  height  weight  disciplines  \
# 0              MEX       0     0.0  ['Archery']
# 1              MEX       0     0.0  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   function country_code country country_full nationality nationality_full  \
# 0  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 1  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  height  weight  disciplines  \
# 0              MEX       0     0.0  ['Archery']
# 1              MEX       0     0.0  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
# Solo lo elimina de la salida, para eliminar del dataframe se usa inplace=True
ed.drop("function", axis=1, inplace=True)
# Si no existe la columna regresa un error

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  height  weight  disciplines  \
# 0              MEX       0     0.0  ['Archery']
# 1              MEX       0     0.0  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
# Tambien se puede con asignacion de la salida
ed = ed.drop("height", axis=1)
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  weight  disciplines  \
# 0              MEX     0.0  ['Archery']
# 1              MEX     0.0  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
# Tambien se puede eliminando el objeto
del ed["weight"]
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %% [markdown]
# ### Drop Rows

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
ed.drop(0, axis=0).head(2)
# Out:
#       code           name name_short        name_tv  gender country_code  \
# 1  1535429    RUIZ Angela     RUIZ A    Angela RUIZ  Female          MEX
# 2  1535430  GRANDE Matias   GRANDE M  Matias GRANDE    Male          MEX
#
#   country country_full nationality nationality_full nationality_code  \
# 1  Mexico       Mexico      Mexico           Mexico              MEX
# 2  Mexico       Mexico      Mexico           Mexico              MEX
#
#    disciplines                                            events  birth_date
# 1  ['Archery']            ["Women's Individual", "Women's Team"]  2006-07-28
# 2  ['Archery']  ["Men's Individual", "Men's Team", 'Mixed Team']  2004-04-26

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
ed.drop([0, 1, 2], axis=0).head(2)
# Out:
#       code                 name       name_short              name_tv gender  \
# 3  1536460         ROJAS Carlos          ROJAS C         Carlos ROJAS   Male
# 4  1536467  MARTINEZ WING Bruno  MARTINEZ WING B  Bruno MARTINEZ WING   Male
#
#   country_code country country_full nationality nationality_full  \
# 3          MEX  Mexico       Mexico      Mexico           Mexico
# 4          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines                              events  \
# 3              MEX  ['Archery']  ["Men's Individual", "Men's Team"]
# 4              MEX  ['Archery']  ["Men's Individual", "Men's Team"]
#
#    birth_date
# 3  2000-01-14
# 4  1998-03-08

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
ed.drop(range(0,10), axis=0).head(2)
# Out:
#        code            name name_short         name_tv  gender country_code  \
# 10  1541266  CORDEAU Amelie  CORDEAU A  Amelie CORDEAU  Female          FRA
# 11  1541268  LOPEZ Caroline    LOPEZ C  Caroline LOPEZ  Female          FRA
#
#    country country_full nationality nationality_full nationality_code  \
# 10  France       France      France           France              FRA
# 11  France       France      France           France              FRA
#
#     disciplines                                  events  birth_date
# 10  ['Archery']  ["Women's Individual", "Women's Team"]  2005-10-01
# 11  ['Archery']  ["Women's Individual", "Women's Team"]  2004-01-09

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %% [markdown]
# ### Add Columns

# %%
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17
# 1             ["Women's Individual", "Women's Team"]  2006-07-28

# %%
ed["NC"] = np.nan
ed.head(2)
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
#
#                                               events  birth_date  NC
# 0  ["Women's Individual", "Women's Team", 'Mixed ...  1994-10-17 NaN
# 1             ["Women's Individual", "Women's Team"]  2006-07-28 NaN

# %%
data = np.arange(0, ed.shape[0])
data = data ** 2
data
# Out:
# array([        0,         1,         4, ..., 123476544, 123498769,
#        123520996])

# %%
ed["rango"] = data
ed.head(5)
# Out:
#       code                 name       name_short              name_tv  gender  \
# 0  1535420   VALENCIA Alejandra       VALENCIA A   Alejandra VALENCIA  Female
# 1  1535429          RUIZ Angela           RUIZ A          Angela RUIZ  Female
# 2  1535430        GRANDE Matias         GRANDE M        Matias GRANDE    Male
# 3  1536460         ROJAS Carlos          ROJAS C         Carlos ROJAS    Male
# 4  1536467  MARTINEZ WING Bruno  MARTINEZ WING B  Bruno MARTINEZ WING    Male
#
#   country_code country country_full nationality nationality_full  \
# 0          MEX  Mexico       Mexico      Mexico           Mexico
# 1          MEX  Mexico       Mexico      Mexico           Mexico
# 2          MEX  Mexico       Mexico      Mexico           Mexico
# 3          MEX  Mexico       Mexico      Mexico           Mexico
# 4          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  disciplines  \
# 0              MEX  ['Archery']
# 1              MEX  ['Archery']
# ...

# %%
ant = ed.shape[0]
# ed2 = ed._append(ed)
ed2 = pd.concat([ed, ed])
now = ed2.shape[0]
ant, now, ed.shape[0]
# Out:
# (11115, 22230, 11115)
