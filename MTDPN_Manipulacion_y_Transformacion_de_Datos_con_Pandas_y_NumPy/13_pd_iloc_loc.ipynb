# %%
import pandas as pd

# %%
df = pd.read_csv('./files/athletes_new.csv')
df
# Out:
#           code                   name       name_short                name_tv  \
# 0      1535420     VALENCIA Alejandra       VALENCIA A     Alejandra VALENCIA
# 1      1535429            RUIZ Angela           RUIZ A            Angela RUIZ
# 2      1535430          GRANDE Matias         GRANDE M          Matias GRANDE
# 3      1536460           ROJAS Carlos          ROJAS C           Carlos ROJAS
# 4      1536467    MARTINEZ WING Bruno  MARTINEZ WING B    Bruno MARTINEZ WING
# ...        ...                    ...              ...                    ...
# 11110  1981775       SULEYMANOV Sanan     SULEYMANOV S       Sanan SULEYMANOV
# 11111  1981785  MAGOMEDOV Magomedkhan      MAGOMEDOV M  Magomedkhan MAGOMEDOV
# 11112  2008688         SACULTAN Maxim       SACULTAN M         Maxim SACULTAN
# 11113  3429662         VALIEV Chermen         VALIEV C         Chermen VALIEV
# 11114  9460001        LIUZZI Emanuela         LIUZZI E        Emanuela LIUZZI
#
# ...

# %%
df[0:4]
# Out:
#       code                name  name_short             name_tv  gender  \
# 0  1535420  VALENCIA Alejandra  VALENCIA A  Alejandra VALENCIA  Female
# 1  1535429         RUIZ Angela      RUIZ A         Angela RUIZ  Female
# 2  1535430       GRANDE Matias    GRANDE M       Matias GRANDE    Male
# 3  1536460        ROJAS Carlos     ROJAS C        Carlos ROJAS    Male
#
#   function country_code country country_full nationality nationality_full  \
# 0  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 1  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 2  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 3  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  height  weight  disciplines  \
# 0              MEX       0     0.0  ['Archery']
# 1              MEX       0     0.0  ['Archery']
# 2              MEX       0     0.0  ['Archery']
# ...

# %%
df[["name", "code", "gender", "country_code"]]
# Out:
#                         name     code  gender country_code
# 0         VALENCIA Alejandra  1535420  Female          MEX
# 1                RUIZ Angela  1535429  Female          MEX
# 2              GRANDE Matias  1535430    Male          MEX
# 3               ROJAS Carlos  1536460    Male          MEX
# 4        MARTINEZ WING Bruno  1536467    Male          MEX
# ...                      ...      ...     ...          ...
# 11110       SULEYMANOV Sanan  1981775    Male          AZE
# 11111  MAGOMEDOV Magomedkhan  1981785    Male          AZE
# 11112         SACULTAN Maxim  2008688    Male          MDA
# 11113         VALIEV Chermen  3429662    Male          ALB
# 11114        LIUZZI Emanuela  9460001  Female          ITA
#
# [11115 rows x 4 columns]

# %%
df.loc[:]
# Out:
#           code                   name       name_short                name_tv  \
# 0      1535420     VALENCIA Alejandra       VALENCIA A     Alejandra VALENCIA
# 1      1535429            RUIZ Angela           RUIZ A            Angela RUIZ
# 2      1535430          GRANDE Matias         GRANDE M          Matias GRANDE
# 3      1536460           ROJAS Carlos          ROJAS C           Carlos ROJAS
# 4      1536467    MARTINEZ WING Bruno  MARTINEZ WING B    Bruno MARTINEZ WING
# ...        ...                    ...              ...                    ...
# 11110  1981775       SULEYMANOV Sanan     SULEYMANOV S       Sanan SULEYMANOV
# 11111  1981785  MAGOMEDOV Magomedkhan      MAGOMEDOV M  Magomedkhan MAGOMEDOV
# 11112  2008688         SACULTAN Maxim       SACULTAN M         Maxim SACULTAN
# 11113  3429662         VALIEV Chermen         VALIEV C         Chermen VALIEV
# 11114  9460001        LIUZZI Emanuela         LIUZZI E        Emanuela LIUZZI
#
# ...

# %%
df.loc[0:4]
# Out:
#       code                 name       name_short              name_tv  gender  \
# 0  1535420   VALENCIA Alejandra       VALENCIA A   Alejandra VALENCIA  Female
# 1  1535429          RUIZ Angela           RUIZ A          Angela RUIZ  Female
# 2  1535430        GRANDE Matias         GRANDE M        Matias GRANDE    Male
# 3  1536460         ROJAS Carlos          ROJAS C         Carlos ROJAS    Male
# 4  1536467  MARTINEZ WING Bruno  MARTINEZ WING B  Bruno MARTINEZ WING    Male
#
#   function country_code country country_full nationality nationality_full  \
# 0  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 1  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 2  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 3  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
# 4  Athlete          MEX  Mexico       Mexico      Mexico           Mexico
#
#   nationality_code  height  weight  disciplines  \
# ...

# %%
df.loc[0:4, ["code", "name", "country_code"]]
# Out:
#       code                 name country_code
# 0  1535420   VALENCIA Alejandra          MEX
# 1  1535429          RUIZ Angela          MEX
# 2  1535430        GRANDE Matias          MEX
# 3  1536460         ROJAS Carlos          MEX
# 4  1536467  MARTINEZ WING Bruno          MEX

# %%
"id-" + df.loc[0:15, "name"]
# Out:
# 0         id-VALENCIA Alejandra
# 1                id-RUIZ Angela
# 2              id-GRANDE Matias
# 3               id-ROJAS Carlos
# 4        id-MARTINEZ WING Bruno
# 5                id-VAZQUEZ Ana
# 6              id-FALLAH Mobina
# 7           id-D'AMOUR Nicholas
# 8       id-AMAISTROAIE Madalina
# 9              id-BARBELIN Lisa
# 10            id-CORDEAU Amelie
# 11            id-LOPEZ Caroline
# 12            id-ADDIS Baptiste
# 13           id-CHIRAULT Thomas
# 14    id-VALLADONT Jean-Charles
# 15                 id-DORJI Lam
# Name: name, dtype: object

# %%
rs = df.loc[0:15, "gender"] == 'Female'
filtrado = df.loc[0:15][rs]
filtrado
# Out:
#        code                  name     name_short               name_tv  \
# 0   1535420    VALENCIA Alejandra     VALENCIA A    Alejandra VALENCIA
# 1   1535429           RUIZ Angela         RUIZ A           Angela RUIZ
# 5   1536479           VAZQUEZ Ana      VAZQUEZ A           Ana VAZQUEZ
# 6   1536632         FALLAH Mobina       FALLAH M         Mobina FALLAH
# 8   1538449  AMAISTROAIE Madalina  AMAISTROAIE M  Madalina AMAISTROAIE
# 9   1541265         BARBELIN Lisa     BARBELIN L         Lisa BARBELIN
# 10  1541266        CORDEAU Amelie      CORDEAU A        Amelie CORDEAU
# 11  1541268        LOPEZ Caroline        LOPEZ C        Caroline LOPEZ
#
#     gender function country_code  country              country_full  \
# 0   Female  Athlete          MEX   Mexico                    Mexico
# 1   Female  Athlete          MEX   Mexico                    Mexico
# 5   Female  Athlete          MEX   Mexico                    Mexico
# ...

# %%
df.iloc[:]
# Out:
#           code                   name       name_short                name_tv  \
# 0      1535420     VALENCIA Alejandra       VALENCIA A     Alejandra VALENCIA
# 1      1535429            RUIZ Angela           RUIZ A            Angela RUIZ
# 2      1535430          GRANDE Matias         GRANDE M          Matias GRANDE
# 3      1536460           ROJAS Carlos          ROJAS C           Carlos ROJAS
# 4      1536467    MARTINEZ WING Bruno  MARTINEZ WING B    Bruno MARTINEZ WING
# ...        ...                    ...              ...                    ...
# 11110  1981775       SULEYMANOV Sanan     SULEYMANOV S       Sanan SULEYMANOV
# 11111  1981785  MAGOMEDOV Magomedkhan      MAGOMEDOV M  Magomedkhan MAGOMEDOV
# 11112  2008688         SACULTAN Maxim       SACULTAN M         Maxim SACULTAN
# 11113  3429662         VALIEV Chermen         VALIEV C         Chermen VALIEV
# 11114  9460001        LIUZZI Emanuela         LIUZZI E        Emanuela LIUZZI
#
# ...

# %%
df.iloc[5:8, 2:4]
# Out:
#   name_short           name_tv
# 5  VAZQUEZ A       Ana VAZQUEZ
# 6   FALLAH M     Mobina FALLAH
# 7  D'AMOUR N  Nicholas D'AMOUR
