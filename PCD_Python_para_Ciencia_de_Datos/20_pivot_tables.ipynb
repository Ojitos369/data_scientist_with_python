# %%
import pandas as pd
from functions import p

# %%
df = pd.read_csv('files/online_retail.csv')
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
df["year"] = df["InvoiceDate"].dt.year
df["month"] = df["InvoiceDate"].dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   year         541909 non-null  int32
#  9   month        541909 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(1), object(4)
# memory usage: 37.2+ MB

# %%
pd.pivot_table(df, values="Quantity", index="Country", aggfunc="sum", columns=["year", "month"])
# Out:
# year                      2010      2011                                \
# month                       12        1         2         3         4
# Country
# Australia                454.0    5644.0    8659.0   10329.0     117.0
# Austria                    3.0       NaN     342.0     982.0     311.0
# Bahrain                   54.0     -54.0       NaN       NaN       NaN
# Belgium                 1755.0     783.0    1097.0    1776.0    1173.0
# Brazil                     NaN       NaN       NaN       NaN     356.0
# Canada                     NaN       NaN       NaN      88.0       NaN
# Channel Islands           80.0     255.0     935.0    2104.0      97.0
# Cyprus                   917.0     144.0    2190.0    1005.0      -4.0
# Czech Republic             NaN       NaN     346.0       NaN     -39.0
# Denmark                  454.0       NaN     224.0     879.0       NaN
# EIRE                    5381.0    8688.0    5328.0    9562.0    4135.0
# ...

# %%
d2 = pd.DataFrame({
    "A": ["foo", "bar", "baz"],
    "B": [1, 2, 3],
    "C": [4, 5, 6],
})

# %%
d2
# Out:
#      A  B  C
# 0  foo  1  4
# 1  bar  2  5
# 2  baz  3  6

# %%
st = d2.stack()
st
# Out:
# 0  A    foo
#    B      1
#    C      4
# 1  A    bar
#    B      2
#    C      5
# 2  A    baz
#    B      3
#    C      6
# dtype: object

# %%
st.unstack()
# Out:
#      A  B  C
# 0  foo  1  4
# 1  bar  2  5
# 2  baz  3  6

# %%
df.stack()
# Out:
# 0       InvoiceNo                                  536365
#         StockCode                                  85123A
#         Description    WHITE HANGING HEART T-LIGHT HOLDER
#         Quantity                                        6
#         InvoiceDate                   2010-12-01 08:26:00
#                                       ...
# 541908  UnitPrice                                    4.95
#         CustomerID                                12680.0
#         Country                                    France
#         year                                         2011
#         month                                          12
# Length: 5282556, dtype: object

# %%
st[0]
# Out:
# A    foo
# B      1
# C      4
# dtype: object

# %%
st[0]["B"], st[0]["A"], st[0]["C"]
# Out:
# (1, 'foo', 4)
