# %%
import pandas as pd
from functions import p

# %%
d1 = pd.DataFrame({
    "key": ["A", "B", "C"],
    "value1": [1, 2, 3]
})

d2 = pd.DataFrame({
    "key": ["B", "C", "D"],
    "value2": [4, 5, 6]
})

# %%
p(d1)
p()
p(d2)
# Out:
#   key  value1
# 0   A       1
# 1   B       2
# 2   C       3
#
#   key  value2
# 0   B       4
# 1   C       5
# 2   D       6

# %%
pd.merge(d1, d2, on="key", how="inner")
# Out:
#   key  value1  value2
# 0   B       2       4
# 1   C       3       5

# %%
pd.merge(d1, d2, on="key", how="left")
# Out:
#   key  value1  value2
# 0   A       1     NaN
# 1   B       2     4.0
# 2   C       3     5.0

# %%
pd.merge(d1, d2, on="key", how="right")
# Out:
#   key  value1  value2
# 0   B     2.0       4
# 1   C     3.0       5
# 2   D     NaN       6

# %%
pd.merge(d1, d2, on="key", how="outer")
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     4.0
# 2   C     3.0     5.0
# 3   D     NaN     6.0

# %%
pd.concat((d1, d2))
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     NaN
# 2   C     3.0     NaN
# 0   B     NaN     4.0
# 1   C     NaN     5.0
# 2   D     NaN     6.0

# %%
pd.concat((d1, d2), axis=0)
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     NaN
# 2   C     3.0     NaN
# 0   B     NaN     4.0
# 1   C     NaN     5.0
# 2   D     NaN     6.0

# %%
pd.concat((d1, d2), axis=1)
# Out:
#   key  value1 key  value2
# 0   A       1   B       4
# 1   B       2   C       5
# 2   C       3   D       6

# %%
pd.concat((d1, d2), axis=0, ignore_index=True)
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     NaN
# 2   C     3.0     NaN
# 3   B     NaN     4.0
# 4   C     NaN     5.0
# 5   D     NaN     6.0

# %%
pd.concat((d1, d2), axis=1, ignore_index=True)
# Out:
#    0  1  2  3
# 0  A  1  B  4
# 1  B  2  C  5
# 2  C  3  D  6

# %%
d3 = pd.DataFrame({
    "A": ["A0", "A1", "A2"],
    "B": ["B0", "B1", "B2"]
})

d4 = pd.DataFrame({
    "A": ["A3", "A4", "A5"],
    "B": ["B3", "B4", "B5"]
})

# %%
# pd.concat((d3, d4), axis=0)
pd.concat((d3, d4))
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5

# %%
pd.concat((d3, d4), ignore_index=True)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5

# %%
pd.concat((d3, d4), axis=1)
# Out:
#     A   B   A   B
# 0  A0  B0  A3  B3
# 1  A1  B1  A4  B4
# 2  A2  B2  A5  B5

# %%
pd.concat((d3, d4), axis=1, ignore_index=True)
# Out:
#     0   1   2   3
# 0  A0  B0  A3  B3
# 1  A1  B1  A4  B4
# 2  A2  B2  A5  B5

# %%
d5 = pd.DataFrame({
    "A": ["A0", "A1", "A2"],
    "B": ["B0", "B1", "B2"]
}, index=["K0", "K1", "K2"])
d6 = pd.DataFrame({
    "C": ["C0", "C1", "C2"],
    "D": ["D0", "D1", "D2"]
}, index=["K0", "K2", "K3"])
p(d5)
p()
p(d6)
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
#
#      C   D
# K0  C0  D0
# K2  C1  D1
# K3  C2  D2

# %%
d5.join(d6, how="inner")
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C1  D1

# %%
d5.join(d6, how="left")
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D1

# %%
d5.join(d6, how="right")
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C1  D1
# K3  NaN  NaN  C2  D2

# %%
d5.join(d6, how="outer")
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C1   D1
# K3  NaN  NaN   C2   D2

# %%
pd.concat((d5, d6), axis=1, join="inner")
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C1  D1
